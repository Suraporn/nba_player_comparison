# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
raw = pd.read_csv('data/player_stats.csv')
raw.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
raw.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
player = raw[['Player', 'Year', 'Pos', 'Tm', 'G',
             'FG%', 'FT%', '3P%', 'ORB%', 'AST%', 
             'BLK%', 'DRB%', 'STL%'
            ]]
player.tail()
# Out:
#                   Player    Year Pos   Tm     G    FG%    FT%    3P%  ORB%  \
# 24686        Cody Zeller  2017.0  PF  CHO  62.0  0.571  0.679  0.000   8.6
# 24687       Tyler Zeller  2017.0   C  BOS  51.0  0.494  0.564  0.000   9.2
# 24688  Stephen Zimmerman  2017.0   C  ORL  19.0  0.323  0.600    NaN  10.8
# 24689        Paul Zipser  2017.0  SF  CHI  44.0  0.398  0.775  0.333   1.9
# 24690        Ivica Zubac  2017.0   C  LAL  38.0  0.529  0.653  0.000   7.1
#
#        AST%  BLK%  DRB%  STL%
# 24686   9.1   3.0  17.3   1.8
# 24687  12.2   3.3  17.0   0.7
# 24688   5.3   3.7  24.9   0.9
# 24689   6.1   1.5  14.2   0.9
# 24690   8.1   4.4  21.9   1.1

# %%
player.shape
# Out:
# (24691, 13)

# %%
player = player.dropna()
player
# Out:
#                      Player    Year Pos   Tm     G    FG%    FT%    3P%  ORB%  \
# 5727   Kareem Abdul-Jabbar*  1980.0   C  LAL  82.0  0.604  0.765  0.000   7.2
# 5728          Tom Abernethy  1980.0  PF  GSW  67.0  0.481  0.683  0.000   5.4
# 5729            Alvan Adams  1980.0   C  PHO  75.0  0.531  0.797  0.000   8.2
# 5730        Tiny Archibald*  1980.0  PG  BOS  80.0  0.482  0.830  0.222   2.3
# 5732             Gus Bailey  1980.0  SG  WSB  20.0  0.457  0.385  1.000   3.3
# ...                     ...     ...  ..  ...   ...    ...    ...    ...   ...
# 24685        Thaddeus Young  2017.0  PF  IND  74.0  0.527  0.523  0.381   6.7
# 24686           Cody Zeller  2017.0  PF  CHO  62.0  0.571  0.679  0.000   8.6
# 24687          Tyler Zeller  2017.0   C  BOS  51.0  0.494  0.564  0.000   9.2
# 24689           Paul Zipser  2017.0  SF  CHI  44.0  0.398  0.775  0.333   1.9
# 24690           Ivica Zubac  2017.0   C  LAL  38.0  0.529  0.653  0.000   7.1
#
#        AST%  BLK%  DRB%  STL%
# 5727   16.5   4.6  22.2   1.2
# 5728    9.3   0.6  12.0   1.4
# 5729   21.6   1.4  22.4   2.3
# 5730   30.2   0.2   5.3   1.7
# 5732   17.8   1.2  12.4   1.8
# ...     ...   ...   ...   ...
# 24685   8.4   1.2  15.8   2.6
# 24686   9.1   3.0  17.3   1.8
# 24687  12.2   3.3  17.0   0.7
# 24689   6.1   1.5  14.2   0.9
# 24690   8.1   4.4  21.9   1.1
#
# [15116 rows x 13 columns]

# %%
player = player.rename(columns={'Player':'Name','Tm':'Team','G':'Game',
             'FG%':'FGp', 'FT%':'FTp', '3P%':'3Pp', 'ORB%':'ORBp', 'AST%':'ASTp', 
             'BLK%':'BLKp', 'DRB%':'DRBp', 'STL%':'STLp'
            })
player['Year'] = player['Year'].astype(int)
player
# Out:
#                        Name  Year Pos Team  Game    FGp    FTp    3Pp  ORBp  \
# 5727   Kareem Abdul-Jabbar*  1980   C  LAL  82.0  0.604  0.765  0.000   7.2
# 5728          Tom Abernethy  1980  PF  GSW  67.0  0.481  0.683  0.000   5.4
# 5729            Alvan Adams  1980   C  PHO  75.0  0.531  0.797  0.000   8.2
# 5730        Tiny Archibald*  1980  PG  BOS  80.0  0.482  0.830  0.222   2.3
# 5732             Gus Bailey  1980  SG  WSB  20.0  0.457  0.385  1.000   3.3
# ...                     ...   ...  ..  ...   ...    ...    ...    ...   ...
# 24685        Thaddeus Young  2017  PF  IND  74.0  0.527  0.523  0.381   6.7
# 24686           Cody Zeller  2017  PF  CHO  62.0  0.571  0.679  0.000   8.6
# 24687          Tyler Zeller  2017   C  BOS  51.0  0.494  0.564  0.000   9.2
# 24689           Paul Zipser  2017  SF  CHI  44.0  0.398  0.775  0.333   1.9
# 24690           Ivica Zubac  2017   C  LAL  38.0  0.529  0.653  0.000   7.1
#
#        ASTp  BLKp  DRBp  STLp
# 5727   16.5   4.6  22.2   1.2
# 5728    9.3   0.6  12.0   1.4
# 5729   21.6   1.4  22.4   2.3
# 5730   30.2   0.2   5.3   1.7
# 5732   17.8   1.2  12.4   1.8
# ...     ...   ...   ...   ...
# 24685   8.4   1.2  15.8   2.6
# 24686   9.1   3.0  17.3   1.8
# 24687  12.2   3.3  17.0   0.7
# 24689   6.1   1.5  14.2   0.9
# 24690   8.1   4.4  21.9   1.1
#
# [15116 rows x 13 columns]

# %%
player = player.tail(3000)
player
# Out:
#                   Name  Year Pos Team  Game    FGp    FTp    3Pp  ORBp  ASTp  \
# 21135       Tony Allen  2012  SG  MEM  58.0  0.469  0.800  0.308   7.4   8.3
# 21136    Morris Almond  2012  SG  WAS   4.0  0.353  0.333  0.333   1.7   4.4
# 21137  Al-Farouq Aminu  2012  SF  NOH  66.0  0.411  0.754  0.277   7.8   7.2
# 21140    Alan Anderson  2012  SF  TOR  17.0  0.387  0.853  0.393   2.1   9.5
# 21141   James Anderson  2012  SG  SAS  51.0  0.379  0.750  0.279   3.1   9.6
# ...                ...   ...  ..  ...   ...    ...    ...    ...   ...   ...
# 24685   Thaddeus Young  2017  PF  IND  74.0  0.527  0.523  0.381   6.7   8.4
# 24686      Cody Zeller  2017  PF  CHO  62.0  0.571  0.679  0.000   8.6   9.1
# 24687     Tyler Zeller  2017   C  BOS  51.0  0.494  0.564  0.000   9.2  12.2
# 24689      Paul Zipser  2017  SF  CHI  44.0  0.398  0.775  0.333   1.9   6.1
# 24690      Ivica Zubac  2017   C  LAL  38.0  0.529  0.653  0.000   7.1   8.1
#
#        BLKp  DRBp  STLp
# 21135   1.8  10.6   3.6
# 21136   0.0  11.9   5.4
# 21137   1.9  16.9   2.2
# 21140   0.5   6.5   0.6
# 21141   0.2  11.8   0.7
# ...     ...   ...   ...
# 24685   1.2  15.8   2.6
# 24686   3.0  17.3   1.8
# 24687   3.3  17.0   0.7
# 24689   1.5  14.2   0.9
# 24690   4.4  21.9   1.1
#
# [3000 rows x 13 columns]

# %%
player['Name'].nunique()
# Out:
# 794

# %%
player_A = 'LeBron James'
player_B = 'Kobe Bryant'

# %%
filter_player = player.loc[(player['Name']==player_A) | (player['Name']==player_B)]
filter_player
# Out:
#                Name  Year Pos Team  Game    FGp    FTp    3Pp  ORBp  ASTp  \
# 12900   Kobe Bryant  1997  SG  LAL  71.0  0.417  0.819  0.375   4.9  13.8
# 13479   Kobe Bryant  1998  SG  LAL  79.0  0.428  0.794  0.341   4.5  16.0
# 14021   Kobe Bryant  1999  SG  LAL  50.0  0.465  0.839  0.267   3.3  17.5
# 14537   Kobe Bryant  2000  SG  LAL  66.0  0.468  0.821  0.319   4.6  22.4
# 15028   Kobe Bryant  2001  SG  LAL  68.0  0.464  0.853  0.305   4.3  23.0
# 15578   Kobe Bryant  2002  SG  LAL  80.0  0.469  0.829  0.250   4.1  25.9
# 16070   Kobe Bryant  2003  SG  LAL  82.0  0.451  0.843  0.383   3.5  27.2
# 16576   Kobe Bryant  2004  SG  LAL  65.0  0.438  0.852  0.327   4.7  24.4
# 16746  LeBron James  2004  SG  CLE  79.0  0.417  0.754  0.290   3.5  27.8
# 17159   Kobe Bryant  2005  SG  LAL  66.0  0.433  0.816  0.339   4.0  28.5
# 17344  LeBron James  2005  SF  CLE  80.0  0.472  0.750  0.351   3.8  32.9
# 17742   Kobe Bryant  2006  SG  LAL  80.0  0.450  0.850  0.347   2.6  24.1
# 17918  LeBron James  2006  SF  CLE  79.0  0.480  0.738  0.335   2.6  32.8
# 18295   Kobe Bryant  2007  SG  LAL  77.0  0.463  0.868  0.344   2.8  25.5
# 18460  LeBron James  2007  SF  CLE  78.0  0.476  0.698  0.319   3.0  29.1
# 18825   Kobe Bryant  2008  SG  LAL  82.0  0.459  0.840  0.361   3.4  23.9
# 19017  LeBron James  2008  SF  CLE  75.0  0.484  0.712  0.315   4.9  37.3
# 19428   Kobe Bryant  2009  SG  LAL  82.0  0.467  0.856  0.351   3.5  23.8
# 19611  LeBron James  2009  SF  CLE  81.0  0.489  0.780  0.344   4.3  38.0
# 20006   Kobe Bryant  2010  SG  LAL  73.0  0.456  0.811  0.329   3.1  23.8
# 20207  LeBron James  2010  SF  CLE  76.0  0.503  0.767  0.333   3.0  41.8
# 20600   Kobe Bryant  2011  SG  LAL  82.0  0.451  0.828  0.323   3.5  26.7
# 20812  LeBron James  2011  SF  MIA  79.0  0.510  0.759  0.330   3.3  34.9
# 21196   Kobe Bryant  2012  SG  LAL  58.0  0.430  0.845  0.303   3.5  23.7
# 21395  LeBron James  2012  SF  MIA  62.0  0.531  0.771  0.362   5.0  33.6
# 21757   Kobe Bryant  2013  SG  LAL  78.0  0.463  0.839  0.324   2.5  29.7
# 21933  LeBron James  2013  PF  MIA  76.0  0.565  0.753  0.406   4.4  36.4
# 22348   Kobe Bryant  2014  SG  LAL   6.0  0.425  0.857  0.188   1.2  34.6
# 22548  LeBron James  2014  PF  MIA  77.0  0.567  0.750  0.379   3.6  32.0
# 22944   Kobe Bryant  2015  SG  LAL  35.0  0.373  0.813  0.293   2.3  29.9
# 23154  LeBron James  2015  SF  CLE  69.0  0.488  0.710  0.354   2.4  38.6
# 23586   Kobe Bryant  2016  SF  LAL  66.0  0.358  0.826  0.285   2.3  19.1
# 23781  LeBron James  2016  SF  CLE  76.0  0.520  0.731  0.309   4.7  36.0
# 24365  LeBron James  2017  SF  CLE  74.0  0.548  0.674  0.363   4.0  41.3
#
#        BLKp  DRBp  STLp
# 12900   1.6   8.7   2.3
# 13479   1.3   8.7   1.8
# 14021   1.9  12.7   2.0
# 14537   1.7  12.9   2.2
# 15028   1.1  11.8   2.1
# 15578   0.8  11.7   2.0
# 16070   1.4  15.3   2.8
# 16576   0.8  12.0   2.4
# 16746   1.3  11.8   2.2
# 17159   1.4  12.4   1.7
# 17344   1.1  17.0   2.8
# 17742   0.7  12.7   2.4
# 17918   1.5  17.1   2.0
# 18295   0.9  13.5   1.8
# 18460   1.3  16.6   2.1
# 18825   0.9  14.1   2.4
# 19017   2.1  17.8   2.4
# 19428   1.0  12.8   2.1
# 19611   2.4  19.0   2.4
# 20006   0.5  12.2   2.1
# 20207   2.0  18.5   2.2
# 20600   0.3  13.3   1.9
# 20812   1.3  18.7   2.1
# 21196   0.6  11.8   1.6
# 21395   1.7  19.7   2.6
# 21757   0.6  13.1   1.8
# 21933   1.9  20.8   2.4
# 22348   0.4  14.5   1.9
# 22548   0.8  18.9   2.2
# 22944   0.5  16.5   2.0
# 23154   1.6  16.6   2.3
# 23586   0.5  12.3   1.7
# 23781   1.5  18.8   2.0
# 24365   1.3  20.7   1.6

# %%
x_min=filter_player['Year'].min()
x_max=filter_player['Year'].max()

# %%
off_selection = 'FGp'

# %%
# Create chart
chart_off = alt.Chart(filter_player).mark_point().encode(
    x = alt.X('Year',scale=alt.Scale(domain=(x_min, x_max))),
    y = off_selection,
    color = alt.Color('Name', title='Player')
)
chart_off
# Out:
# alt.Chart(...)
